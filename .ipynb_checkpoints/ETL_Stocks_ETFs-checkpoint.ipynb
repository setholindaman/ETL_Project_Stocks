# %%
# Import dependencies
import pandas as pd
from sqlalchemy import create_engine
import datetime

# %% [markdown]
# ### Stocks

# %%
stocks_url = 'https://finance.yahoo.com/most-active?offset=0&count=50'
tables = pd.read_html(stocks_url)
stock_df = tables[0]
stock_df.head()
# Out:
#   Symbol                     Name  Price (Intraday)  Change % Change   Volume  \
# 0      F       Ford Motor Company              8.25    0.01   +0.12%  65.393M
# 1   CSCO      Cisco Systems, Inc.             47.32   -2.61   -5.23%  47.045M
# 2      S       Sprint Corporation              8.67    0.07   +0.81%  45.387M
# 3    NIO              NIO Limited              4.03   -0.04   -0.98%  36.859M
# 4    KHC  The Kraft Heinz Company             27.77   -2.27   -7.56%  37.334M
#
#   Avg Vol (3 month) Market Cap  PE Ratio (TTM)  52 Week Range
# 0           47.476M    32.711B          825.00            NaN
# 1           20.114M   205.098B           18.83            NaN
# 2           18.694M    35.981B             NaN            NaN
# 3           71.047M     4.023B             NaN            NaN
# 4            6.338M    33.945B             NaN            NaN

# %%
# Remove trailing letter and then convert datatype on the series of 'Market Cap' and 'Volume'
market_cap_cleaned = stock_df['Market Cap'].str.rstrip('B,T')
    
volume_cleaned = stock_df['Volume'].str.rstrip('M')
percent_change = stock_df['% Change'].str.rstrip('%')

market_cap_converted = market_cap_cleaned.astype(float)
volume_converted = volume_cleaned.astype(float)
percent_change_converted = percent_change.astype(float)

stock_df.drop(labels = 'Market Cap', axis=1, inplace=True)
stock_df.drop(labels = 'Volume', axis=1, inplace=True)
stock_df.drop(labels = '% Change', axis=1, inplace=True)

stock_df['Market Cap ($Bil.)'] = market_cap_converted
stock_df['Volume (Mil.)'] = volume_converted
stock_df['Percent_Change'] = percent_change_converted

# %%
stock_df.head()
# Out:
#   Symbol                     Name  Price (Intraday)  Change Avg Vol (3 month)  \
# 0      F       Ford Motor Company              8.25    0.01           47.476M
# 1   CSCO      Cisco Systems, Inc.             47.32   -2.61           20.114M
# 2      S       Sprint Corporation              8.67    0.07           18.694M
# 3    NIO              NIO Limited              4.03   -0.04           71.047M
# 4    KHC  The Kraft Heinz Company             27.77   -2.27            6.338M
#
#    PE Ratio (TTM)  52 Week Range  Market Cap ($Bil.)  Volume (Mil.)  \
# 0          825.00            NaN              32.711         65.393
# 1           18.83            NaN             205.098         47.045
# 2             NaN            NaN              35.981         45.387
# 3             NaN            NaN               4.023         36.859
# 4             NaN            NaN              33.945         37.334
#
#    Percent_Change
# 0            0.12
# 1           -5.23
# 2            0.81
# 3           -0.98
# 4           -7.56

# %%
stock_df['Time'] = datetime.datetime.now()
stock_df_filtered = stock_df[stock_df['Market Cap ($Bil.)'] > 100]

stock_df_filtered.reset_index(drop=True, inplace=True)

# %%
stock_df_filtered.head()
# Out:
#   Symbol                           Name  Price (Intraday)  Change  \
# 0   CSCO            Cisco Systems, Inc.             47.32   -2.61
# 1    BAC    Bank of America Corporation             34.91   -0.01
# 2   BABA  Alibaba Group Holding Limited            220.36   -3.95
# 3   TSLA                    Tesla, Inc.            804.00   36.71
# 4    PFE                    Pfizer Inc.             36.93   -0.81
#
#   Avg Vol (3 month)  PE Ratio (TTM)  52 Week Range  Market Cap ($Bil.)  \
# 0           20.114M           18.83            NaN             205.098
# 1           43.743M           12.69            NaN             308.470
# 2           15.364M           63.01            NaN             602.806
# 3           15.582M             NaN            NaN             144.917
# 4           21.362M           12.86            NaN             204.375
#
#    Volume (Mil.)  Percent_Change                       Time
# 0         47.045           -5.23 2020-02-13 19:56:26.492840
# 1         28.230           -0.03 2020-02-13 19:56:26.492840
# 2         27.470           -1.76 2020-02-13 19:56:26.492840
# 3         26.289            4.78 2020-02-13 19:56:26.492840
# 4         20.374           -2.15 2020-02-13 19:56:26.492840

# %%
pd.savefig('stock_df.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-a5a20c61439f> in <module>()
# ----> 1 pd.savefig('stock_df.png')
#
# AttributeError: module 'pandas' has no attribute 'savefig'

# %%
print(datetime.datetime.now())
# Out:
# 2020-02-13 20:00:25.444308

# %%
rds_connection_string = "root:Greenman!98@localhost"
engine = create_engine(f'mysql://{rds_connection_string}')

# %%
engine.execute('CREATE DATABASE IF NOT EXISTS wolves_db')

# %%
engine.execute('USE wolves_db')

# %%
stock_df_filtered.to_sql(name='market_data', con=engine, if_exists='append', index=False)

# %% [markdown]
# ### ETF's

# %%
etf_url = 'https://finance.yahoo.com/etfs'
tables = pd.read_html(etf_url)
etf_df = tables[0]
etf_df.head()
# Out:
#   Symbol                                Name  Price (Intraday)  Change  \
# 0    XLU   Utilities Select Sector SPDR Fund             69.92    0.77
# 1   XMMO     Invesco S&P MidCap Momentum ETF             64.90    0.67
# 2    IDU          iShares U.S. Utilities ETF            174.44    1.77
# 3   FUTY   Fidelity MSCI Utilities Index ETF             45.55    0.52
# 4    PUI  Invesco DWA Utilities Momentum ETF             37.14    0.36
#
#   % Change   Volume  50 Day Average  200 Day Average  52 Week Range
# 0   +1.11%  13.394M           66.68            63.83            NaN
# 1   +1.04%   100180           62.68            59.77            NaN
# 2   +1.03%    31873          166.79           160.26            NaN
# 3   +1.15%   178459           43.50            41.81            NaN
# 4   +0.97%    20583           35.40            34.28            NaN

# %%
percent_change = etf_df['% Change'].str.rstrip('%')
percent_change_converted = percent_change.astype(float)
etf_df.drop(labels = '% Change', axis=1, inplace=True)
etf_df['Percent_Change'] = percent_change_converted

etf_df.drop(labels = '52 Week Range', axis=1, inplace=True)
etf_df['Time'] = datetime.datetime.now()

# %%
etf_df.head()
# Out:
#   Symbol                                Name  Price (Intraday)  Change  \
# 0    XLU   Utilities Select Sector SPDR Fund             69.92    0.77
# 1   XMMO     Invesco S&P MidCap Momentum ETF             64.90    0.67
# 2    IDU          iShares U.S. Utilities ETF            174.44    1.77
# 3   FUTY   Fidelity MSCI Utilities Index ETF             45.55    0.52
# 4    PUI  Invesco DWA Utilities Momentum ETF             37.14    0.36
#
#     Volume  50 Day Average  200 Day Average  Percent_Change  \
# 0  13.394M           66.68            63.83            1.11
# 1   100180           62.68            59.77            1.04
# 2    31873          166.79           160.26            1.03
# 3   178459           43.50            41.81            1.15
# 4    20583           35.40            34.28            0.97
#
#                         Time
# 0 2020-02-13 20:01:16.474530
# 1 2020-02-13 20:01:16.474530
# 2 2020-02-13 20:01:16.474530
# 3 2020-02-13 20:01:16.474530
# 4 2020-02-13 20:01:16.474530

# %%
engine.execute('USE wolves_db')

# %%
stock_df_filtered.to_sql(name='etf_data', con=engine, if_exists='append', index=False)
